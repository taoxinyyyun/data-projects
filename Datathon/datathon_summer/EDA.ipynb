# %% [markdown]
# ### EDA
# Sample Question 2: Investigate the neighborhoods that have higher or lower Airbnb rental activity. Are there any notable demographic patterns that emerge between such neighborhoods?
#
# Sample Question 3: Are there any interesting differences in Airbnb rental activity between areas with different real estate values and economic characteristics?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### 1.1 Data Exploring

# %%
# listings data.
listings = pd.read_csv('listings.csv')
print(listings.head())
print("\n-------------------------------------------------------------------------------------\n")
print(listings.info())
listings.describe(include='all').transpose()
# Out:
#    accommodates                                          amenities  \
# 0           2.0  {"Wireless Internet","Air Conditioning",Kitche...
# 1           4.0  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 2           1.0  {TV,"Wireless Internet","Air Conditioning",Kit...
# 3           6.0  {Internet,"Wireless Internet","Air Conditionin...
# 4           6.0  {Internet,"Wireless Internet","Free Parking on...
#
#    availability_30  bathrooms  bed_type  bedrooms  beds cancellation_policy  \
# 0                0        1.0  Real Bed       1.0   1.0            moderate
# 1               17        1.0  Real Bed       1.0   2.0              strict
# 2               29        1.0  Real Bed       1.0   1.0            flexible
# 3               28        2.5  Real Bed       1.0   6.0            moderate
# 4               25        2.5  Real Bed       1.0   6.0            moderate
#
#         city  has_availability  ...  review_scores_checkin  \
# 0  Asheville               NaN  ...                   10.0
# 1  Asheville               NaN  ...                   10.0
# 2  Asheville               NaN  ...                    NaN
# 3  Asheville               NaN  ...                    NaN
# 4  Asheville               NaN  ...                   10.0
#
#    review_scores_cleanliness review_scores_communication  \
# 0                        9.0                        10.0
# 1                       10.0                        10.0
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        9.0                         9.0
#
#    review_scores_location  review_scores_rating review_scores_value  \
# 0                     9.0                  96.0                10.0
# 1                     9.0                  96.0                 9.0
# 2                     NaN                   NaN                 NaN
# 3                     NaN                   NaN                 NaN
# 4                     9.0                  93.0                10.0
#
#          room_type state weekly_price  zipcode
# 0  Entire home/apt    NC      $650.00  28806.0
# 1  Entire home/apt    NC          NaN  28806.0
# 2     Private room    NC          NaN  28806.0
# 3      Shared room    NC          NaN  28806.0
# 4      Shared room    NC          NaN  28806.0
#
# [5 rows x 29 columns]
#
# -------------------------------------------------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50321 entries, 0 to 50320
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   accommodates                 50321 non-null  float64
#  1   amenities                    50321 non-null  object
#  2   availability_30              50321 non-null  int64
#  3   bathrooms                    50174 non-null  float64
#  4   bed_type                     50321 non-null  object
#  5   bedrooms                     50277 non-null  float64
#  6   beds                         50229 non-null  float64
#  7   cancellation_policy          50321 non-null  object
#  8   city                         50321 non-null  object
#  9   has_availability             0 non-null      float64
#  10  host_id                      50321 non-null  int64
#  11  id                           50321 non-null  int64
#  12  instant_bookable             50321 non-null  object
#  13  latitude                     50321 non-null  float64
#  14  longitude                    50321 non-null  float64
#  15  metropolitan                 50321 non-null  object
#  16  name                         50313 non-null  object
#  17  price                        50321 non-null  object
#  18  property_type                50321 non-null  object
#  19  review_scores_checkin        37540 non-null  float64
#  20  review_scores_cleanliness    37590 non-null  float64
#  21  review_scores_communication  37589 non-null  float64
#  22  review_scores_location       37537 non-null  float64
#  23  review_scores_rating         37646 non-null  float64
#  24  review_scores_value          37522 non-null  float64
#  25  room_type                    50321 non-null  object
#  26  state                        50321 non-null  object
#  27  weekly_price                 11476 non-null  object
#  28  zipcode                      49741 non-null  object
# dtypes: float64(13), int64(3), object(13)
# memory usage: 11.1+ MB
# None
#                                count unique              top   freq  \
# accommodates                 50321.0    NaN              NaN    NaN
# amenities                      50321  44220               {}    592
# availability_30              50321.0    NaN              NaN    NaN
# bathrooms                    50174.0    NaN              NaN    NaN
# bed_type                       50321      5         Real Bed  49062
# bedrooms                     50277.0    NaN              NaN    NaN
# beds                         50229.0    NaN              NaN    NaN
# cancellation_policy            50321      6           strict  22277
# city                           50321    195      los angeles  19515
# has_availability                 0.0    NaN              NaN    NaN
# host_id                      50321.0    NaN              NaN    NaN
# id                           50321.0    NaN              NaN    NaN
# instant_bookable               50321      2                f  36620
# latitude                     50321.0    NaN              NaN    NaN
# longitude                    50321.0    NaN              NaN    NaN
# metropolitan                   50321      5               LA  31211
# name                           50313  49557     Private room     11
# price                          50321    882          $150.00   1713
# property_type                  50321     38            House  23530
# review_scores_checkin        37540.0    NaN              NaN    NaN
# review_scores_cleanliness    37590.0    NaN              NaN    NaN
# review_scores_communication  37589.0    NaN              NaN    NaN
# review_scores_location       37537.0    NaN              NaN    NaN
# review_scores_rating         37646.0    NaN              NaN    NaN
# review_scores_value          37522.0    NaN              NaN    NaN
# room_type                      50321      3  Entire home/apt  31586
# state                          50321      7               CA  31209
# weekly_price                   11476   1033          $500.00    476
# zipcode                        49741    429          78704.0   1994
#
#                                         mean              std         min  \
# accommodates                        3.845094          2.67786         1.0
# amenities                                NaN              NaN         NaN
# availability_30                    13.903877        11.331614         0.0
# bathrooms                           1.418942         0.818857         0.0
# bed_type                                 NaN              NaN         NaN
# bedrooms                            1.497126         1.066181         0.0
# beds                                2.058572          1.63397         0.0
# cancellation_policy                      NaN              NaN         NaN
# city                                     NaN              NaN         NaN
# has_availability                         NaN              NaN         NaN
# host_id                      34542818.832992  33615990.835299        23.0
# id                           10459158.231196   5531892.584147       109.0
# instant_bookable                         NaN              NaN         NaN
# latitude                           33.061129         1.964399   29.898266
# longitude                        -108.732058        12.659095 -118.911026
# metropolitan                             NaN              NaN         NaN
# name                                     NaN              NaN         NaN
# price                                    NaN              NaN         NaN
# property_type                            NaN              NaN         NaN
# review_scores_checkin               9.807991         0.601507         2.0
# review_scores_cleanliness            9.48896         0.901592         2.0
# review_scores_communication         9.806938         0.598274         2.0
# review_scores_location              9.591603         0.733792         2.0
# review_scores_rating               94.781677         7.458544        20.0
# review_scores_value                 9.524093         0.797987         2.0
# room_type                                NaN              NaN         NaN
# state                                    NaN              NaN         NaN
# weekly_price                             NaN              NaN         NaN
# zipcode                                  NaN              NaN         NaN
#
#                                     25%         50%         75%          max
# accommodates                        2.0         3.0         5.0         16.0
# amenities                           NaN         NaN         NaN          NaN
# availability_30                     1.0        13.0        25.0         30.0
# bathrooms                           1.0         1.0         2.0          8.0
# bed_type                            NaN         NaN         NaN          NaN
# bedrooms                            1.0         1.0         2.0         10.0
# beds                                1.0         1.0         3.0         16.0
# cancellation_policy                 NaN         NaN         NaN          NaN
# city                                NaN         NaN         NaN          NaN
# has_availability                    NaN         NaN         NaN          NaN
# host_id                       6793558.0  23535330.0  52316725.0  132838425.0
# id                            5659901.0  11377381.0  15391723.0   19038571.0
# instant_bookable                    NaN         NaN         NaN          NaN
# latitude                      30.298556   34.038303   34.101816    36.366593
# longitude                   -118.372711 -118.248865  -97.729191   -82.417304
# metropolitan                        NaN         NaN         NaN          NaN
# name                                NaN         NaN         NaN          NaN
# price                               NaN         NaN         NaN          NaN
# property_type                       NaN         NaN         NaN          NaN
# review_scores_checkin              10.0        10.0        10.0         10.0
# review_scores_cleanliness           9.0        10.0        10.0         10.0
# review_scores_communication        10.0        10.0        10.0         10.0
# review_scores_location              9.0        10.0        10.0         10.0
# review_scores_rating               93.0        97.0       100.0        100.0
# review_scores_value                 9.0        10.0        10.0         10.0
# room_type                           NaN         NaN         NaN          NaN
# state                               NaN         NaN         NaN          NaN
# weekly_price                        NaN         NaN         NaN          NaN
# zipcode                             NaN         NaN         NaN          NaN

# %%
# Check duplicates.
listings.duplicated().sum()
# Out:
# 0

# %%
# Check null values.
listings.isnull().sum()
# Out:
# accommodates                       0
# amenities                          0
# availability_30                    0
# bathrooms                        147
# bed_type                           0
# bedrooms                          44
# beds                              92
# cancellation_policy                0
# city                               0
# has_availability               50321
# host_id                            0
# id                                 0
# instant_bookable                   0
# latitude                           0
# longitude                          0
# metropolitan                       0
# name                               8
# price                              0
# property_type                      0
# review_scores_checkin          12781
# review_scores_cleanliness      12731
# review_scores_communication    12732
# review_scores_location         12784
# review_scores_rating           12675
# review_scores_value            12799
# room_type                          0
# state                              0
# weekly_price                   38845
# zipcode                          580
# log_price                          0
# dtype: int64

# %%
# Pre-clean the dataset and convert datatypes into usable formats.
price_str = listings['price'].str[1:-3]
listings['price'] = price_str.str.extract('(\d+)').astype(int)
listings['price']
# Out:
# 0        105
# 1        125
# 2         45
# 3         24
# 4         24
#         ...
# 50316     75
# 50317    205
# 50318    500
# 50319     65
# 50320    500
# Name: price, Length: 50321, dtype: int64

# %%
# Distribution of regions.
freq=listings['state'].value_counts().sort_values(ascending=True)
freq.plot.barh(figsize=(10, 8), color='blue', grid=True, width=1)
plt.title("Number of listings by state", fontsize=20)
plt.xlabel('Number of listings', fontsize=12)
plt.show()

# %%
# Only one listing in DC and one listing in OR.
OR=listings[listings['state']=='OR']
OR
# Out:
#       accommodates                                          amenities  \
# 8990           2.0  {Internet,"Wireless Internet","Air conditionin...
#
#       availability_30  bathrooms       bed_type  bedrooms  beds  \
# 8990               30        1.0  Pull-out Sofa       1.0   1.0
#
#      cancellation_policy      city  has_availability  ...  \
# 8990            flexible  portland               NaN  ...
#
#       review_scores_checkin  review_scores_cleanliness  \
# 8990                    NaN                        NaN
#
#      review_scores_communication  review_scores_location  \
# 8990                         NaN                     NaN
#
#       review_scores_rating review_scores_value    room_type  state  \
# 8990                   NaN                 NaN  Shared room     OR
#
#      weekly_price  zipcode
# 8990          NaN  97202.0
#
# [1 rows x 29 columns]

# %%
# Property types.
listings.property_type.unique()
# Out:
# array(['House', 'Tent', 'Dorm', 'Bed & Breakfast', 'Villa', 'Apartment',
#        'Loft', 'Camper/RV', 'Townhouse', 'Bungalow', 'Cabin', 'Treehouse',
#        'Earth House', 'Other', 'Yurt', 'Condominium', 'Chalet',
#        'Guesthouse', 'Boutique hotel', 'Serviced apartment', 'Boat',
#        'Nature lodge', 'Lighthouse', 'Island', 'Tipi', 'Hostel',
#        'Entire Floor', 'Castle', 'Guest suite', 'Timeshare', 'Train',
#        'Vacation home', 'In-law', 'Plane', 'Hut', 'Parking Space',
#        'Casa particular', 'Cave'], dtype=object)

# %%
# Visualize distribution of property types.
freq2=listings['property_type'].value_counts().sort_values(ascending=True)
freq2.drop(freq2[freq2 < 100].index, inplace=True)
freq2.plot.barh(figsize=(10, 8), color='blue', grid=True, width=1)
plt.title("Number of listings by state", fontsize=20)
plt.xlabel('Number of listings', fontsize=12)
plt.show()

# %%
# Visualize distribution of property types by room types.
group1 = listings.groupby(['property_type','room_type']).room_type.count()
group1 = group1.unstack()
group1['total'] = group1.iloc[:,0:3].sum(axis = 1)
group1 = group1.sort_values(by=['total'])
group1 = group1[group1['total']>=100]
group1 = group1.drop(columns=['total'])

group1.plot(kind='barh', color = ["r","b","g"],
              linewidth = 1, grid=True, figsize=(15,8), width=1)
plt.title('Property types in South Region', fontsize=18)
plt.xlabel('Number of listings', fontsize=14)
plt.legend(loc = 4,prop = {"size" : 13})
plt.rc('ytick', labelsize=13)
plt.show()

# %%
# Visualization of Maps
import matplotlib.pyplot as plt
# %matplotlib inline
import mplleaflet as mpll

listings_TX = listings[listings['state'] == 'TX']
listings_LA = listings[listings['state'] == 'LA']
listings_TN = listings[listings['state'] == 'TN']
listings_NC = listings[listings['state'] == 'NC']
listings_CA = listings[listings['state'] == 'CA']

# f, ax = plt.subplots(figsize=(15, 10))

# listings_TX.plot(kind='scatter', x='longitude', y='latitude', s=3, color='blue', linewidth=1, ax=ax)

# mpll.display()

fig, ax = plt.subplots(3,2,figsize=(10,10))
listings_CA.plot(x='longitude',y='latitude', c='log_price',kind='scatter',cmap='jet',ax=ax[0][0],zorder=5)
ax[0][0].set_xlabel('', fontsize=12)
ax[0][0].set_title('Distribution of Airbnb in CA', fontsize=12)
listings_TX.plot(x='longitude',y='latitude', c='log_price',kind='scatter',cmap='jet',ax=ax[0][1],zorder=5)
ax[0][1].set_xlabel('', fontsize=12)
ax[0][1].set_title('Distribution of Airbnb in TX', fontsize=12)
listings_LA.plot(x='longitude',y='latitude', c='log_price',kind='scatter',cmap='jet',ax=ax[1][0],zorder=5)
ax[1][0].set_xlabel('', fontsize=12)
ax[1][0].set_title('LA', fontsize=12)
listings_TN.plot(x='longitude',y='latitude', c='log_price',kind='scatter',cmap='jet',ax=ax[1][1],zorder=5)
ax[1][1].set_xlabel('', fontsize=12)
ax[1][1].set_title('TN', fontsize=12)
listings_NC.plot(x='longitude',y='latitude', c='log_price',kind='scatter',cmap='jet',ax=ax[2][0],zorder=5)
ax[2][0].set_title('NC', fontsize=12)
# Out:
# Text(0.5, 1.0, 'NC')

# %% [markdown]
# ### 1.2 Listing Price

# %%
plt.figure(figsize=(10,8))
sns.distplot(listings['price'],kde = False)
plt.show()

# %%
# Need to do normalization.
listings['log_price'] = np.log(listings['price']+1)

plt.figure(figsize=(10,8))
sns.distplot(listings['log_price'],kde = False)
plt.show()

# %%
plt.figure(figsize=(15,10))

#Categorizing log_price into neighbourhood_group for differnt room types
#Looks like entire home/apt are more likely to have a higher price.
sns.boxplot(x="room_type", y="log_price",hue="state",data=listings)
plt.title('Price range of different room types in different states')
plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)

# %%
wk_price = listings['weekly_price'].str[1:-3]
listings['weekly_price'] = wk_price.str.extract('(\d+)').astype(float)
listings['weekly_price']
# Out:
# 0        650.0
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 50316      NaN
# 50317      NaN
# 50318      NaN
# 50319      NaN
# 50320      NaN
# Name: weekly_price, Length: 50321, dtype: float64

# %%
# Find correlation among the variables. We use kendall correlation here because the assumption is non-parametric.
listings = listings.drop(['has_availability'], axis=1)
corr = listings.corr(method='kendall')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Import calendar, real_estate, venues data.
calendar = pd.read_csv('calendar.csv.gz', compression='gzip')
real_estate = pd.read_csv('real_estate.csv.gz', compression='gzip')
venues = pd.read_csv('venues.csv.gz', compression='gzip')

# %%
# Calendar dataset.
calendar['price'].isnull().sum()
# Out:
# 8561996

# %%
calendar[calendar['available'] == 't'].head(20)
# Out:
#     listing_id        date available  price metro_area
# 39      665257  2016-05-31         t  105.0  asheville
# 40      665257  2016-06-01         t  105.0  asheville
# 41      665257  2016-06-02         t  105.0  asheville
# 42      665257  2016-06-03         t  105.0  asheville
# 43      665257  2016-06-04         t  105.0  asheville
# 44      665257  2016-06-05         t  105.0  asheville
# 45      665257  2016-06-06         t  105.0  asheville
# 46      665257  2016-06-07         t  105.0  asheville
# 47      665257  2016-06-08         t  105.0  asheville
# 48      665257  2016-06-09         t  105.0  asheville
# 49      665257  2016-06-10         t  105.0  asheville
# 50      665257  2016-06-11         t  105.0  asheville
# 51      665257  2016-06-12         t  105.0  asheville
# 52      665257  2016-06-13         t  105.0  asheville
# 53      665257  2016-06-14         t  105.0  asheville
# 54      665257  2016-06-15         t  105.0  asheville
# 55      665257  2016-06-16         t  105.0  asheville
# 56      665257  2016-06-17         t  105.0  asheville
# 57      665257  2016-06-18         t  105.0  asheville
# 58      665257  2016-06-19         t  105.0  asheville

# %%
calendar.listing_id.value_counts()
# Out:
# 18332319    730
# 17480730    730
# 13941107    730
# 17424700    365
# 10139861    365
#            ...
# 13700159    365
# 9651318     365
# 17463120    365
# 16648670    365
# 17882596    365
# Name: listing_id, Length: 50364, dtype: int64

# %%
price_str2 = calendar['price'].str[1:-3]
calendar['price'] = price_str2.str.extract('(\d+)').astype(float).round(0)
calendar['price']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#             ..
# 18383950   NaN
# 18383951   NaN
# 18383952   NaN
# 18383953   NaN
# 18383954   NaN
# Name: price, Length: 18383955, dtype: float64

# %%
calendar['date'] = pd.to_datetime(calendar['date'])
print(calendar.head())
print("\n-------------------------------------------------------------------------------------\n")
print(calendar.info())
calendar.describe(include='all').transpose()
# Out:
#    listing_id       date available  price metro_area
# 0      665257 2016-04-22         f    NaN  asheville
# 1      665257 2016-04-23         f    NaN  asheville
# 2      665257 2016-04-24         f    NaN  asheville
# 3      665257 2016-04-25         f    NaN  asheville
# 4      665257 2016-04-26         f    NaN  asheville
#
# -------------------------------------------------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383955 entries, 0 to 18383954
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   listing_id  int64
#  1   date        datetime64[ns]
#  2   available   object
#  3   price       float64
#  4   metro_area  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 701.3+ MB
# None
# <ipython-input-187-586734ddb976>:5: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   calendar.describe(include='all').transpose()
#                  count unique                  top      freq      first  \
# listing_id  18383955.0    NaN                  NaN       NaN        NaT
# date          18383955    773  2017-07-24 00:00:00     49503 2016-04-20
# available     18383955      2                    t   9821959        NaT
# price        9821959.0    NaN                  NaN       NaN        NaT
# metro_area    18383955      5                   LA  11408440        NaT
#
#                  last             mean             std    min        25%  \
# listing_id        NaT  10461463.836738  5531408.170981  109.0  5661043.0
# date       2018-06-01              NaN             NaN    NaN        NaN
# available         NaT              NaN             NaN    NaN        NaN
# price             NaT       172.097202      162.302439    1.0       75.0
# metro_area        NaT              NaN             NaN    NaN        NaN
#
#                    50%         75%         max
# listing_id  11378190.0  15392750.0  19038571.0
# date               NaN         NaN         NaN
# available          NaN         NaN         NaN
# price            120.0       200.0       999.0
# metro_area         NaN         NaN         NaN

# %%
# Now we want to check for seasonality in the supply.
calendar_avl = calendar[['date', 'available']]
calendar_avl['available'] = calendar_avl.available.map( lambda x: 0 if x == 'f' else 1)
calendar_avl = calendar_avl.groupby('date')['available'].mean().reset_index()

plt.figure(figsize=(10, 5))
plt.plot(calendar_avl['date'], calendar_avl['available'])
plt.title('US South Airbnb Calendar')
plt.ylabel('% available')
plt.show();
# Out:
# <ipython-input-145-30c9ddb7bb29>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calendar_avl['available'] = calendar_avl.available.map( lambda x: 0 if x == 'f' else 1)

# %%
# We also want to see if there are day of week effects in the calendar data.
calendar['dayofweek'] = calendar['date'].dt.day_name()
days = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
price_week=calendar[calendar.price.notnull()][['dayofweek','price']]
price_week = calendar.groupby(['dayofweek']).mean().reindex(days)
price_week.drop('listing_id', axis=1, inplace=True)

plt.figure(figsize=(10, 5))
plt.plot(price_week)
plt.title('Average Listing Prices by Day of Week')
plt.ylabel('dollars ($)')
plt.grid()
plt.show()
# ticks = list(range(0, 7, 1)) # points on the x axis where you want the label to appear
# labels = "Mon Tues Weds Thurs Fri Sat Sun".split()
# plt.xticks(ticks, labels)

# %%
# demographics data.
demographics = pd.read_csv('demographics.csv')
print(demographics.head())
print("\n-------------------------------------------------------------------------------------\n")
print(demographics.info())
demographics.describe(include='all').transpose()
# Out:
#    zipcode  population  5_years_or_less  5-9_years  10-14_years  15-19_years  \
# 0      601       17982            17982       1006         1080         1342
# 1      602       40260            40260       2006         2440         2421
# 2      603       52408            52408       2664         3177         3351
# 3      606        6331             6331        347          331          461
# 4      610       28328            28328       1438         1490         2044
#
#    20-24_years  25-34_years  35-44_years  45-54_years  ...  $10,000-$14,999  \
# 0         1352         1321         2253         2149  ...             48.1
# 1         2953         2865         5124         5139  ...             31.4
# 2         3685         3585         6473         6775  ...               31
# 3          474          469          707          933  ...             45.3
# 4         2122         1985         3358         3778  ...             26.9
#
#    $15,000-$24,999  $25,000-$34,999  $35,000-$49,999  $50,000-$64,999  \
# 0               12             12.8              8.6              8.7
# 1             16.3             17.9             12.2             10.6
# 2             14.9             17.5             11.7             10.8
# 3             10.2               20             11.7               11
# 4             14.8             23.7             15.2              9.3
#
#    $65,000-$74,999  $75,000-$99,999 $100,000_or_more median_household_income  \
# 0              6.2              1.4             16.3                   10816
# 1              7.7              2.9             21.2                   16079
# 2              8.7              2.4             21.9                   16804
# 3              1.8                0             12.8                   12512
# 4              7.5              1.6             18.4                   17475
#
#   mean_household_income
# 0                 20349
# 1                 23282
# 2                 26820
# 3                 15730
# 4                 23360
#
# [5 rows x 27 columns]
#
# -------------------------------------------------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   zipcode                  33120 non-null  int64
#  1   population               33120 non-null  int64
#  2   5_years_or_less          33120 non-null  int64
#  3   5-9_years                33120 non-null  int64
#  4   10-14_years              33120 non-null  int64
#  5   15-19_years              33120 non-null  int64
#  6   20-24_years              33120 non-null  int64
#  7   25-34_years              33120 non-null  int64
#  8   35-44_years              33120 non-null  int64
#  9   45-54_years              33120 non-null  int64
#  10  55-59_years              33120 non-null  int64
#  11  60-64_years              33120 non-null  int64
#  12  65-74_years              33120 non-null  int64
#  13  75-84_years              33120 non-null  int64
#  14  85_years_or_more         33120 non-null  int64
#  15  households               33120 non-null  int64
#  16  $9,999_or_less           33120 non-null  int64
#  17  $10,000-$14,999          33120 non-null  object
#  18  $15,000-$24,999          33120 non-null  object
#  19  $25,000-$34,999          33120 non-null  object
#  20  $35,000-$49,999          33120 non-null  object
#  21  $50,000-$64,999          33120 non-null  object
#  22  $65,000-$74,999          33120 non-null  object
#  23  $75,000-$99,999          33120 non-null  object
#  24  $100,000_or_more         33120 non-null  object
#  25  median_household_income  33120 non-null  object
#  26  mean_household_income    33120 non-null  object
# dtypes: int64(17), object(10)
# memory usage: 6.8+ MB
# None
#                            count unique      top  freq          mean  \
# zipcode                  33120.0    NaN      NaN   NaN  49666.334209
# population               33120.0    NaN      NaN   NaN   9664.375151
# 5_years_or_less          33120.0    NaN      NaN   NaN   9664.375151
# 5-9_years                33120.0    NaN      NaN   NaN    607.095622
# 10-14_years              33120.0    NaN      NaN   NaN    625.481582
# 15-19_years              33120.0    NaN      NaN   NaN    631.631975
# 20-24_years              33120.0    NaN      NaN   NaN    652.501872
# 25-34_years              33120.0    NaN      NaN   NaN    690.229831
# 35-44_years              33120.0    NaN      NaN   NaN   1308.378019
# 45-54_years              33120.0    NaN      NaN   NaN   1241.185296
# 55-59_years              33120.0    NaN      NaN   NaN   1339.541033
# 60-64_years              33120.0    NaN      NaN   NaN    640.693448
# 65-74_years              33120.0    NaN      NaN   NaN    562.563557
# 75-84_years              33120.0    NaN      NaN   NaN    769.238013
# 85_years_or_more         33120.0    NaN      NaN   NaN    414.395592
# households               33120.0    NaN      NaN   NaN    181.439312
# $9,999_or_less           33120.0    NaN      NaN   NaN   3567.898521
# $10,000-$14,999            33120    523        0  2898           NaN
# $15,000-$24,999            33120    419        0  3161           NaN
# $25,000-$34,999            33120    554        0  1658           NaN
# $35,000-$49,999            33120    520        0  1706           NaN
# $50,000-$64,999            33120    564        0  1339           NaN
# $65,000-$74,999            33120    615        0  1095           NaN
# $75,000-$99,999            33120    507        0  1908           NaN
# $100,000_or_more           33120    831  #VALUE!   571           NaN
# median_household_income    33120  19384        -  1090           NaN
# mean_household_income      33120  25781        -   577           NaN
#
#                                   std    min       25%      50%       75%  \
# zipcode                  27564.925769  601.0  26634.75  49739.0   72123.5
# population               14237.949376    0.0    718.75   2808.0  13139.25
# 5_years_or_less          14237.949376    0.0    718.75   2808.0  13139.25
# 5-9_years                 1004.262799    0.0      33.0    150.0     754.0
# 10-14_years               1004.665379    0.0      37.0    165.0     794.0
# 15-19_years                998.328444    0.0      39.0    175.0     814.0
# 20-24_years               1044.958346    0.0      41.0    177.0    826.25
# 25-34_years               1262.651196    0.0      33.0    156.0     798.0
# 35-44_years               2203.234802    0.0      67.0    292.0   1549.25
# 45-54_years                1951.60322    0.0      74.0    322.0    1598.0
# 55-59_years               1955.630562    0.0      99.0    407.0   1833.25
# 60-64_years                898.968127    0.0      53.0    208.0     903.0
# 65-74_years                781.595041    0.0      48.0    189.0     795.0
# 75-84_years               1078.771062    0.0      70.0    266.0    1083.0
# 85_years_or_more           616.141822    0.0      35.0    136.0    556.25
# households                 298.078153    0.0       9.0     48.0     226.0
# $9,999_or_less            5120.549026    0.0     273.0   1059.5   4932.25
# $10,000-$14,999                   NaN    NaN       NaN      NaN       NaN
# $15,000-$24,999                   NaN    NaN       NaN      NaN       NaN
# $25,000-$34,999                   NaN    NaN       NaN      NaN       NaN
# $35,000-$49,999                   NaN    NaN       NaN      NaN       NaN
# $50,000-$64,999                   NaN    NaN       NaN      NaN       NaN
# $65,000-$74,999                   NaN    NaN       NaN      NaN       NaN
# $75,000-$99,999                   NaN    NaN       NaN      NaN       NaN
# $100,000_or_more                  NaN    NaN       NaN      NaN       NaN
# median_household_income           NaN    NaN       NaN      NaN       NaN
# mean_household_income             NaN    NaN       NaN      NaN       NaN
#
#                               max
# zipcode                   99929.0
# population               114982.0
# 5_years_or_less          114982.0
# 5-9_years                 16998.0
# 10-14_years               13509.0
# 15-19_years               10411.0
# 20-24_years               12815.0
# 25-34_years               24060.0
# 35-44_years               26926.0
# 45-54_years               18739.0
# 55-59_years               15710.0
# 60-64_years                7298.0
# 65-74_years                8129.0
# 75-84_years               26787.0
# 85_years_or_more          11167.0
# households                 4074.0
# $9,999_or_less            43456.0
# $10,000-$14,999               NaN
# $15,000-$24,999               NaN
# $25,000-$34,999               NaN
# $35,000-$49,999               NaN
# $50,000-$64,999               NaN
# $65,000-$74,999               NaN
# $75,000-$99,999               NaN
# $100,000_or_more              NaN
# median_household_income       NaN
# mean_household_income         NaN

# %%
# econ_state data.
econ_state = pd.read_csv('econ_state.csv')
print(econ_state.head())
print("\n-------------------------------------------------------------------------------------\n")
print(econ_state.info())
econ_state.describe(include='all').transpose()
# Out:
#   state  2005Q1_gdp  2005Q2_gdp  2005Q3_gdp  2005Q4_gdp  2006Q1_gdp  \
# 0    AL      153332      155940      157437      160293      161934
# 1    AK       37517       38907       40691       43138       42872
# 2    AZ      218206      224496      231629      235099      241787
# 3    AR       88446       89264       90515       93050       93413
# 4    CA     1722091     1747827     1787427     1809426     1857944
#
#    2006Q2_gdp  2006Q3_gdp  2006Q4_gdp  2007Q1_gdp  ...  2016/03_ur  \
# 0      163974      165470      166495      166821  ...         6.6
# 1       44653       45349       45840       46658  ...         5.9
# 2      244659      250886      256505      258078  ...         4.1
# 3       95259       95481       95203       94289  ...         5.5
# 4     1865835     1886549     1907754     1915172  ...         5.6
#
#    2016/04_ur  2016/05_ur  2016/06_ur  2016/07_ur  2016/08_ur  2016/09_ur  \
# 0         6.6         6.6         6.7         6.7         6.7         6.6
# 1         5.8         5.8         5.8         5.8         5.9         6.0
# 2         4.1         4.1         4.1         4.0         4.0         4.0
# 3         5.4         5.3         5.3         5.2         5.1         5.1
# 4         5.5         5.5         5.5         5.4         5.4         5.3
#
#    2016/10_ur  2016/11_ur  2016/12_ur
# 0         6.6         6.6         6.6
# 1         6.1         6.2         6.3
# 2         4.0         4.0         3.9
# 3         5.0         5.0         5.0
# 4         5.3         5.3         5.2
#
# [5 rows x 519 columns]
#
# -------------------------------------------------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Columns: 519 entries, state to 2016/12_ur
# dtypes: float64(204), int64(314), object(1)
# memory usage: 206.9+ KB
# None
#            count unique  top freq           mean            std      min  \
# state         51     51   WI    1            NaN            NaN      NaN
# 2005Q1_gdp  51.0    NaN  NaN  NaN  249731.333333  303362.563159  23276.0
# 2005Q2_gdp  51.0    NaN  NaN  NaN  252863.019608  307696.335944  23371.0
# 2005Q3_gdp  51.0    NaN  NaN  NaN  257382.078431  314473.029475  23584.0
# 2005Q4_gdp  51.0    NaN  NaN  NaN  260820.588235  319010.938811  23924.0
# ...          ...    ...  ...  ...            ...            ...      ...
# 2016/08_ur  51.0    NaN  NaN  NaN       4.658824       0.985328      2.9
# 2016/09_ur  51.0    NaN  NaN  NaN       4.637255       0.982031      2.8
# 2016/10_ur  51.0    NaN  NaN  NaN       4.596078       0.995181      2.8
# 2016/11_ur  51.0    NaN  NaN  NaN       4.570588       0.998458      2.8
# 2016/12_ur  51.0    NaN  NaN  NaN       4.533333       0.993915      2.7
#
#                 25%       50%       75%        max
# state           NaN       NaN       NaN        NaN
# 2005Q1_gdp  64611.5  145585.0  315219.5  1722091.0
# 2005Q2_gdp  65307.5  146010.0  319147.0  1747827.0
# 2005Q3_gdp  66352.0  147654.0  322202.0  1787427.0
# 2005Q4_gdp  67785.0  150891.0  326355.0  1809426.0
# ...             ...       ...       ...        ...
# 2016/08_ur      4.0       4.9       5.3        6.8
# 2016/09_ur      4.0       4.9       5.3        6.8
# 2016/10_ur      4.0       4.8       5.2        6.8
# 2016/11_ur      4.0       4.8       5.2        6.7
# 2016/12_ur     3.95       4.7       5.1        6.7
#
# [519 rows x 11 columns]

# %%
econ_state.head(30)
# Out:
#    state  2005Q1_gdp  2005Q2_gdp  2005Q3_gdp  2005Q4_gdp  2006Q1_gdp  \
# 0     AL      153332      155940      157437      160293      161934
# 1     AK       37517       38907       40691       43138       42872
# 2     AZ      218206      224496      231629      235099      241787
# 3     AR       88446       89264       90515       93050       93413
# 4     CA     1722091     1747827     1787427     1809426     1857944
# 5     CO      216906      218710      222780      223421      229476
# 6     CT      207262      210134      210233      213052      221025
# 7     DE       52121       51156       51480       58232       55333
# 8     DC       82522       83530       83845       84446       86260
# 9     FL      680384      690146      713393      717145      733443
# 10    GA      382630      385693      389084      395960      398352
# 11    HI       57292       57899       58808       60292       60789
# 12    ID       46081       46552       47671       48399       49746
# 13    IL      578667      582842      591622      592637      615525
# 14    IN      241447      244158      247138      248044      252329
# 15    IA      122288      122953      124622      123550      125449
# 16    KS      103556      104356      106062      105561      111117
# 17    KY      140387      142877      145260      146978      150120
# 18    LA      193024      198572      201489      205646      205367
# 19    ME       45683       46019       46329       47079       47439
# 20    MD      256743      260562      267518      270412      273950
# 21    MA      340432      342535      348151      349117      354949
# 22    MI      395900      396144      394163      394456      394181
# 23    MN      240282      241430      247510      246510      247295
# 24    MS       79851       80399       81618       84846       84026
# 25    MO      220734      222751      224961      227916      229786
# 26    MT       29850       30064       30771       31864       31972
# 27    NE       71931       72716       73896       75278       75815
# 28    NV      114121      118872      119741      122404      125382
# 29    NH       56375       57047       58067       57638       58791
#
#     2006Q2_gdp  2006Q3_gdp  2006Q4_gdp  2007Q1_gdp  ...  2016/03_ur  \
# 0       163974      165470      166495      166821  ...         6.6
# 1        44653       45349       45840       46658  ...         5.9
# 2       244659      250886      256505      258078  ...         4.1
# 3        95259       95481       95203       94289  ...         5.5
# 4      1865835     1886549     1907754     1915172  ...         5.6
# 5       229632      234160      234411      237933  ...         3.3
# 6       220596      220677      223380      235095  ...         5.4
# 7        56670       56397       55606       56466  ...         6.2
# 8        86981       89166       87577       90741  ...         4.4
# 9       740698      747163      763377      760435  ...         4.9
# 10      401421      406890      410161      409825  ...         5.5
# 11       61704       62641       63080       63904  ...         3.1
# 12       51212       51166       52504       53374  ...         3.8
# 13      616144      620846      632411      640519  ...         3.9
# 14      255039      257997      260372      263018  ...         6.1
# 15      128167      127893      130333      134095  ...         4.7
# 16      113175      113829      115327      119861  ...         4.1
# 17      152391      153077      152943      153224  ...         5.1
# 18      207440      209072      208148      205618  ...         6.2
# 19       48210       48315       49281       48722  ...         4.1
# 20      275749      279362      281476      282680  ...         4.4
# 21      359528      358472      369278      372780  ...         3.7
# 22      396699      397143      394177      403171  ...         4.9
# 23      253525      248666      250622      253242  ...         3.9
# 24       86227       87040       87871       88894  ...         4.5
# 25      233699      233398      234296      234599  ...         6.0
# 26       32590       33362       33731       34903  ...         4.2
# 27       78650       77548       78175       80449  ...         5.1
# 28      128691      128691      130479      130427  ...         3.3
# 29       59052       59766       62179       60859  ...         3.2
#
#     2016/04_ur  2016/05_ur  2016/06_ur  2016/07_ur  2016/08_ur  2016/09_ur  \
# 0          6.6         6.6         6.7         6.7         6.7         6.6
# 1          5.8         5.8         5.8         5.8         5.9         6.0
# 2          4.1         4.1         4.1         4.0         4.0         4.0
# 3          5.4         5.3         5.3         5.2         5.1         5.1
# 4          5.5         5.5         5.5         5.4         5.4         5.3
# 5          3.3         3.4         3.4         3.4         3.3         3.2
# 6          5.4         5.3         5.2         5.1         4.9         4.8
# 7          6.1         6.1         6.1         6.0         6.0         5.9
# 8          4.4         4.4         4.4         4.4         4.3         4.3
# 9          4.9         4.9         4.9         4.9         4.9         4.9
# 10         5.4         5.3         5.3         5.3         5.3         5.4
# 11         3.1         3.1         3.1         3.0         3.0         3.0
# 12         3.8         3.8         3.8         3.7         3.7         3.6
# 13         3.8         3.8         3.8         3.8         3.8         3.8
# 14         6.0         5.9         5.9         5.8         5.8         5.8
# 15         4.7         4.6         4.5         4.5         4.4         4.3
# 16         4.1         4.1         4.2         4.2         4.3         4.3
# 17         5.0         5.0         5.0         5.0         5.0         5.0
# 18         6.2         6.2         6.2         6.2         6.1         6.1
# 19         4.0         3.8         3.7         3.6         3.4         3.3
# 20         4.4         4.3         4.3         4.3         4.2         4.2
# 21         3.8         3.9         3.9         4.0         4.0         4.0
# 22         4.9         4.8         4.8         4.9         4.9         5.0
# 23         3.8         3.9         3.9         3.9         4.0         4.0
# 24         4.5         4.6         4.7         4.8         4.8         4.7
# 25         6.0         5.9         5.9         5.9         5.8         5.7
# 26         4.2         4.2         4.2         4.1         4.1         4.1
# 27         5.0         5.0         4.9         4.9         5.0         5.1
# 28         3.3         3.3         3.2         3.1         3.1         3.1
# 29         3.2         3.2         3.2         3.2         3.2         3.3
#
#     2016/10_ur  2016/11_ur  2016/12_ur
# 0          6.6         6.6         6.6
# 1          6.1         6.2         6.3
# 2          4.0         4.0         3.9
# 3          5.0         5.0         5.0
# 4          5.3         5.3         5.2
# 5          3.1         3.0         3.0
# 6          4.6         4.5         4.4
# 7          5.8         5.8         5.7
# 8          4.3         4.3         4.3
# 9          4.9         4.9         4.9
# 10         5.4         5.5         5.5
# 11         2.9         2.9         2.9
# 12         3.6         3.5         3.5
# 13         3.7         3.7         3.6
# 14         5.8         5.8         5.7
# 15         4.2         4.1         4.0
# 16         4.3         4.3         4.3
# 17         4.9         4.9         4.8
# 18         6.1         6.0         6.0
# 19         3.2         3.1         3.1
# 20         4.2         4.2         4.2
# 21         3.9         3.8         3.8
# 22         5.0         5.1         5.1
# 23         4.0         4.0         4.0
# 24         4.6         4.5         4.4
# 25         5.7         5.6         5.5
# 26         4.0         4.0         4.0
# 27         5.1         5.2         5.2
# 28         3.0         3.0         3.0
# 29         3.3         3.3         3.3
#
# [30 rows x 519 columns]

# %%
real_estate.head(20)
# Out:
#     type  zipcode           city state                           metro  \
# 0   ZHVI    10025       New York    NY                        New York
# 1   ZHVI    60657        Chicago    IL                         Chicago
# 2   ZHVI    60614        Chicago    IL                         Chicago
# 3   ZHVI    79936        El Paso    TX                         El Paso
# 4   ZHVI    60640        Chicago    IL                         Chicago
# 5   ZHVI    77084        Houston    TX                         Houston
# 6   ZHVI    94109  San Francisco    CA                   San Francisco
# 7   ZHVI    75070       McKinney    TX               Dallas-Fort Worth
# 8   ZHVI    11226       New York    NY                        New York
# 9   ZHVI    77449        Cypress    TX                         Houston
# 10  ZHVI    10016       New York    NY                        New York
# 11  ZHVI    32162   The Villages    FL                    The Villages
# 12  ZHVI    60647        Chicago    IL                         Chicago
# 13  ZHVI    37211      Nashville    TN                       Nashville
# 14  ZHVI    90250      Hawthorne    CA  Los Angeles-Long Beach-Anaheim
# 15  ZHVI    37013      Nashville    TN                       Nashville
# 16  ZHVI    60618        Chicago    IL                         Chicago
# 17  ZHVI    10128       New York    NY                        New York
# 18  ZHVI    28269      Charlotte    NC                       Charlotte
# 19  ZHVI    30349      Riverdale    GA                         Atlanta
#
#            county  size_rank   1996-04   1996-05   1996-06  ...  2016-09  \
# 0        New York          1       NaN       NaN       NaN  ...  1137500
# 1            Cook          2  146700.0  146500.0  146300.0  ...   318200
# 2            Cook          3  198000.0  195500.0  194200.0  ...   401900
# 3         El Paso          4   70800.0   71000.0   71000.0  ...   113800
# 4            Cook          5  102300.0  101300.0  100700.0  ...   198800
# 5          Harris          6   75600.0   75400.0   75100.0  ...   160400
# 6   San Francisco          7  298200.0  295700.0  296400.0  ...  1105500
# 7          Collin          8       NaN       NaN       NaN  ...   298800
# 8           Kings          9       NaN       NaN       NaN  ...   583600
# 9          Harris         10   72100.0   72300.0   72100.0  ...   160500
# 10       New York         11       NaN       NaN       NaN  ...   934800
# 11         Sumter         12   91800.0   92100.0   91800.0  ...   246900
# 12           Cook         13  124500.0  124000.0  123600.0  ...   317100
# 13       Davidson         14   80900.0   81600.0   82500.0  ...   204500
# 14    Los Angeles         15       NaN       NaN       NaN  ...   537200
# 15       Davidson         16   89300.0   90200.0   91100.0  ...   169700
# 16           Cook         17  140900.0  140300.0  139500.0  ...   325300
# 17       New York         18       NaN       NaN       NaN  ...  1074900
# 18    Mecklenburg         19  103300.0  104000.0  104700.0  ...   168600
# 19        Clayton         20   90400.0   87900.0   86100.0  ...   101600
#
#     2016-10  2016-11    2016-12  2017-01  2017-02  2017-03  2017-04  2017-05  \
# 0   1137700  1152700  1156000.0  1140200  1130000  1131900  1149600  1198400
# 1    318100   318800   320200.0   320800   322000   323800   326100   327800
# 2    406000   414100   417800.0   417400   418400   414100   404100   406400
# 3    113900   114100   114500.0   114900   115000   114700   114700   114800
# 4    199200   200100   201500.0   203000   205100   206700   206500   206200
# 5    160300   160400   159200.0   157000   154700   153500   154200   156700
# 6   1109500  1118200  1125900.0  1128200  1128700  1131900  1138700  1144600
# 7    301000   303400   304800.0   305600   307400   309800   312100   314100
# 8    594800   605200   612100.0   612800   616900   628900   644200   653500
# 9    161800   162600   161600.0   159100   156400   155200   156400   159400
# 10   946000   949200   950000.0   951800   960100   972200   986900  1021200
# 11   247300   247200   247000.0   247100   247300   247600   248100   248200
# 12   320500   323800   326700.0   329200   331200   332400   333000   334300
# 13   207500   210500   213400.0   215600   217100   218900   222100   224900
# 14   543500   551400   556900.0   561000   564500   568200   571600   574600
# 15   171800   173900   175800.0   177000   178000   179800   182200   184600
# 16   327000   328600   332100.0   334700   335500   335100   334200   334000
# 17  1076400  1090300  1111300.0  1133100  1154700  1189800  1241000  1288200
# 18   169900   171100   172300.0   173400   174300   175200   176000   177300
# 19   104000   107200   110500.0   113300   115400   115700   114100   113700
#
#     2017-06
# 0   1247000
# 1    329100
# 2    415500
# 3    114700
# 4    206700
# 5    158200
# 6   1147900
# 7    315300
# 8    658700
# 9    161000
# 10  1061200
# 11   247900
# 12   335400
# 13   226800
# 14   577000
# 15   186600
# 16   334600
# 17  1318300
# 18   178800
# 19   114800
#
# [20 rows x 262 columns]

# %%
venues.head(20)
# Out:
#          city                                        id   latitude  longitude  \
# 0   asheville  8736e812595db852ccab223019a477b918b64d4d  35.442805 -82.264081
# 1   asheville  479c99c6cc5aa91a6161fecc48bd24258a74bd58  35.564035 -82.278943
# 2   asheville  3e41ce673ee203416cb6f44894e49b2ee93347b1  35.564140 -82.278953
# 3   asheville  ce0b0e6fc251f546370fed20d39778ea796e5475  35.646791 -82.299074
# 4   asheville  f60446561634f4d44e6563dcf17f2b65eb4096f2  35.752135 -82.273258
# 5   asheville  a5dbad21d509663843a5057c4f4ac5ea179661aa  35.608196 -82.318476
# 6   asheville  27ca7c828ec648d41b27a0aa922f805abbd13be4  35.606098 -82.319344
# 7   asheville  fe0365647fd1637fb8c356243542d669485fba3b  35.603353 -82.318356
# 8   asheville  f260f46319a6054b22e26d6d61d1784c9ed05a39  35.608196 -82.318476
# 9   asheville  5b93738190a308683fcc380eb92dcf3a6b272478  35.608165 -82.319634
# 10  asheville  0e824d570595dc411de39581a58042c2c7dd07e8  35.609414 -82.318172
# 11  asheville  dc0bed3ee3e510d9bb8101090bb658564a91e16c  35.609888 -82.320051
# 12  asheville  8a50a84ee1e5349bdd09adf4644a590ff738588f  35.603342 -82.317979
# 13  asheville  4f69f8a3ca8ce43d5755b1629945a5901933421c  35.614405 -82.319442
# 14  asheville  78ebacdcab9786184ab40e175881fa69b0703641  35.613685 -82.319271
# 15  asheville  d95385ad85aedcae63f7ca088aadcd6d0f130576  35.615941 -82.321549
# 16  asheville  d6c53c3f2316500159ef3a934d8a7d0b19183d45  35.619003 -82.318416
# 17  asheville  4b68c9e8c8b827421e921a08d6e17344e1d55b55  35.616695 -82.320466
# 18  asheville  4660c27389f8cb0bcd65dd5166fc0ab61a629b82  35.616653 -82.321027
# 19  asheville  7508fb8c1addeb5a07c831d8cbcad7355077b135  35.619769 -82.316425
#
#                                      name  rating  \
# 0          The Esmeralda Inn & Restaurant     4.4
# 1                       Straightaway Cafe     4.5
# 2                       straightaway cafe     NaN
# 3                    The Huckleberry Cafe     5.0
# 4   Mount Mitchell State Park- Restaurant     4.0
# 5                                 Wendy's     3.7
# 6                    Phil's Bar-B-Que Pit     4.3
# 7                              Sake Sushi     4.7
# 8       Tar Heel Capital Corporation No 2     5.0
# 9                               Taco Bell     3.4
# 10                                Denny's     3.6
# 11                             McDonald's     3.2
# 12                  The Black Bear Tavern     4.7
# 13                   SUBWAYå¨ Restaurants     3.4
# 14                              Pizza Hut     3.7
# 15                             Thai Basil     4.4
# 16       Fresh Wood Fired Pizza and Pasta     4.6
# 17                   Veranda Cafe & Gifts     4.6
# 18              My Father's Pizza & Pasta     4.4
# 19                         The Red Radish     5.0
#
#                                                 types
# 0   ['lodging', 'restaurant', 'food', 'point_of_in...
# 1   ['restaurant', 'food', 'point_of_interest', 'e...
# 2   ['restaurant', 'food', 'point_of_interest', 'e...
# 3   ['restaurant', 'food', 'point_of_interest', 'e...
# 4   ['restaurant', 'food', 'point_of_interest', 'e...
# 5   ['restaurant', 'food', 'point_of_interest', 'e...
# 6   ['restaurant', 'food', 'point_of_interest', 'e...
# 7   ['restaurant', 'food', 'point_of_interest', 'e...
# 8   ['restaurant', 'food', 'point_of_interest', 'e...
# 9   ['meal_takeaway', 'restaurant', 'food', 'point...
# 10  ['restaurant', 'food', 'point_of_interest', 'e...
# 11  ['cafe', 'restaurant', 'food', 'store', 'point...
# 12  ['bar', 'restaurant', 'food', 'point_of_intere...
# 13  ['restaurant', 'food', 'point_of_interest', 'e...
# 14  ['meal_delivery', 'meal_takeaway', 'restaurant...
# 15  ['restaurant', 'food', 'point_of_interest', 'e...
# 16  ['restaurant', 'food', 'point_of_interest', 'e...
# 17  ['restaurant', 'food', 'point_of_interest', 'e...
# 18  ['restaurant', 'food', 'point_of_interest', 'e...
# 19  ['bakery', 'meal_takeaway', 'grocery_or_superm...

# %%
passenger = pd.read_excel('Airport_passenger.xlsx')

# %%
passenger.head(20)
# Out:
#          City  Year  Month  Passenger
# 0   Asheville  2002     10    22043.0
# 1   Asheville  2002     11    18349.0
# 2   Asheville  2002     12    17203.0
# 3   Asheville  2003      1    11490.0
# 4   Asheville  2003      2    12069.0
# 5   Asheville  2003      3    14204.0
# 6   Asheville  2003      4    15070.0
# 7   Asheville  2003      5    17843.0
# 8   Asheville  2003      6    21966.0
# 9   Asheville  2003      7    23865.0
# 10  Asheville  2003      8    21110.0
# 11  Asheville  2003      9    18408.0
# 12  Asheville  2003     10    23634.0
# 13  Asheville  2003     11    18504.0
# 14  Asheville  2003     12    19529.0
# 15  Asheville  2004      1    13193.0
# 16  Asheville  2004      2    13320.0
# 17  Asheville  2004      3    16620.0
# 18  Asheville  2004      4    19381.0
# 19  Asheville  2004      5    21595.0

# %%
passenger['Year_month'] = pd.to_datetime(passenger[['Year', 'Month']].assign(DAY=1))

# %%
passenger['Year_month'] = passenger['Year_month'].dt.strftime('%Y-%m')

# %%
passenger
# Out:
#              City  Year  Month  Passenger Year_month
# 0       Asheville  2002     10    22043.0    2002-10
# 1       Asheville  2002     11    18349.0    2002-11
# 2       Asheville  2002     12    17203.0    2002-12
# 3       Asheville  2003      1    11490.0    2003-01
# 4       Asheville  2003      2    12069.0    2003-02
# ...           ...   ...    ...        ...        ...
# 1105  Los Angeles  2020     11   993921.0    2020-11
# 1106  Los Angeles  2020     12   913498.0    2020-12
# 1107  Los Angeles  2021      1        NaN    2021-01
# 1108  Los Angeles  2021      2        NaN    2021-02
# 1109  Los Angeles  2021      3        NaN    2021-03
#
# [1110 rows x 5 columns]

# %%
passenger_1 = passenger[['City', 'Year_month', 'Passenger']]

# %%
passenger_1
# Out:
#              City Year_month  Passenger
# 0       Asheville    2002-10    22043.0
# 1       Asheville    2002-11    18349.0
# 2       Asheville    2002-12    17203.0
# 3       Asheville    2003-01    11490.0
# 4       Asheville    2003-02    12069.0
# ...           ...        ...        ...
# 1105  Los Angeles    2020-11   993921.0
# 1106  Los Angeles    2020-12   913498.0
# 1107  Los Angeles    2021-01        NaN
# 1108  Los Angeles    2021-02        NaN
# 1109  Los Angeles    2021-03        NaN
#
# [1110 rows x 3 columns]

# %%
passenger_1.to_csv('passenger_data.csv')

# %%
p2 = passenger_1.copy()

# %%
estab = pd.read_excel('2009_estab.xlsx')

# %%
estab
# Out:
#            MSA  Establishment
# 0       Austin          40281
# 1    Asheville          11639
# 2  Los Angeles         333006
# 3    Nashville          37883
# 4  New Orleans          29100

# %%
google = pd.read_csv('multiTimeline_.csv', header=None, names = ['month', 'airbnb'])

# %%
google = google.iloc[2:, :]

# %%
google['airbnb'].replace({"<1":0}, inplace=True)

# %%
google['airbnb'] = google['airbnb'].astype(int)

# %%
google['month'] = pd.to_datetime(google['month']).dt.strftime('%Y-%m')

# %%
google
# Out:
#        month  airbnb
# 2    2009-01       0
# 3    2009-02       0
# 4    2009-03       0
# 5    2009-04       0
# 6    2009-05       0
# ..       ...     ...
# 129  2019-08      91
# 130  2019-09      77
# 131  2019-10      74
# 132  2019-11      69
# 133  2019-12      67
#
# [132 rows x 2 columns]

# %%
google.to_csv('google_index.csv')

# %%
estab.to_csv('09_estab.csv')

# %%
def get_log_hpi(df, city):
  df_city = df[df['city'] == city].copy()
  df_city['log HPI'] = np.log(df_city['housing price index'])
  df_city = df_city.drop(['city','housing price index'], axis=1)
  df_city['date'] = pd.to_datetime(df_city['Year_month'])
  df_city = df_city[df_city['date'] < "2020-01-01"]

  baseline = df_city[df_city['Year_month'] == '2012-01']['log HPI'].iloc[0]
  std = np.std(df_city['log HPI'])
  df_city['log HPI'] = (df_city['log HPI'] - baseline)/std
  df_city = df_city.rename(columns = {'log HPI': city})
  df_city = df_city.drop(columns = 'date')
  return df_city

# %%
hpi_log_la = get_log_hpi(hpi,'Los Angeles')
hpi_log_NO = get_log_hpi(hpi, 'New Orleans')
hpi_log_NA = get_log_hpi(hpi, 'Nashville')
hpi_log_Aus = get_log_hpi(hpi, 'Austin')
hpi_log_Ash = get_log_hpi(hpi, 'Asheville')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-263-b40b234177a5> in <module>
# ----> 1 hpi_log_la = get_log_hpi(hpi,'Los Angeles')
#       2 hpi_log_NO = get_log_hpi(hpi, 'New Orleans')
#       3 hpi_log_NA = get_log_hpi(hpi, 'Nashville')
#       4 hpi_log_Aus = get_log_hpi(hpi, 'Austin')
#       5 hpi_log_Ash = get_log_hpi(hpi, 'Asheville')
#
# NameError: name 'hpi' is not defined

# %%
ax = hpi_log_Ash.plot(x='Year_month', y='Asheville', colormap='Dark2', figsize=(14, 7))
ax.set_xlabel('Year')
ax.set_ylabel('log House Price Index')
ax.set_title('Zillow Home Value Index')

hpi_log_NO.plot(x='Year_month', y='New Orleans', ax=ax)
hpi_log_NA.plot(x='Year_month', y='Nashville', ax=ax)
hpi_log_Aus.plot(x='Year_month', y='Austin', ax=ax)
hpi_log_la.plot(x='Year_month', y='Los Angeles', ax=ax)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-264-08d263e0836e> in <module>
# ----> 1 ax = hpi_log_Ash.plot(x='Year_month', y='Asheville', colormap='Dark2', figsize=(14, 7))
#       2 ax.set_xlabel('Year')
#       3 ax.set_ylabel('log House Price Index')
#       4 ax.set_title('Zillow Home Value Index')
#       5
#
# NameError: name 'hpi_log_Ash' is not defined

# %%
ax = google.plot(x='month', y='airbnb', colormap='prism', figsize=(14, 7))
ax.set_xlabel('Year')
ax.set_ylabel('Google Search Index')
ax.set_title('Google Search Index for Airbnb')
plt.grid()
plt.show()
